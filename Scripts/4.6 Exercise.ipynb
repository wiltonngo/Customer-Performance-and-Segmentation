# %%
# import libaries
import pandas as pd
import numpy as np
import os

# %%
# Create a Path
path = r'/Users/wiltonngo/InstaCart Basket Analysis'

# %%
# import orders_products_combined
df_product_combined = pd.read_pickle(os.path.join(path, 'Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
df_products = pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', 'products_checked.csv'))

# %%
# Drop '_merge' column for df_orders_products_combined
df_product_combined = df_product_combined.drop(columns = ['_merge'])

# %%
df_product_combined.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_since_last_order  product_id  add_to_cart_order  reordered
# 0                    NaN         196                  1          0
# 1                    NaN       14084                  2          0
# 2                    NaN       12427                  3          0
# 3                    NaN       26088                  4          0
# 4                    NaN       26405                  5          0

# %%
df_product_combined.shape
# Out:
# (32434489, 10)

# %%
df_products.drop(columns = ['Unnamed: 0'],inplace = True)

# %%
df_products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
df_products.shape
# Out:
# (49672, 5)

# %%
# Step 5. Determine a suitable way to combine the orders_products_combined dataframe with your products data set:
df_order_products_merged = df_product_combined.merge(df_products, on = 'product_id', indicator = True)

# %%
df_order_products_merged
# Out:
#           order_id  user_id  order_number  order_day_of_week  \
# 0          2539329        1             1                  2
# 1          2398795        1             2                  3
# 2           473747        1             3                  3
# 3          2254736        1             4                  4
# 4           431534        1             5                  4
# ...            ...      ...           ...                ...
# 32404854   1320836   202557            17                  2
# 32404855     31526   202557            18                  5
# 32404856    758936   203436             1                  2
# 32404857   2745165   203436             2                  3
# 32404858   3093936   205420             1                  4
#
#           order_hour_of_day  days_since_last_order  product_id  \
# 0                         8                    NaN         196
# 1                         7                   15.0         196
# ...

# %%
df_order_products_merged[df_order_products_merged['order_hour_of_day'] == 3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 df_order_products_merged[df_order_products_merged['order_hour_of_day'] == 3]
#
# NameError: name 'df_order_products_merged' is not defined

# %%
df_order_products_merged

# %%
# Step 6. Confirm the results of the merge using the merge flag:
df_order_products_merged['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
# Check df_merged size
df_order_products_merged.shape
# Out:
# (32404859, 14)

# %%
# Step 7. Export the newly created dataframe as orders_products_merged in a suitable format:
df_order_products_merged.to_pickle(os.path.join(path, 'Data','Prepared Data', 'orders_products_merged.pkl'))
